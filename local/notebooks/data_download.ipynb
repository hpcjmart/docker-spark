# %% [markdown]
# # Data Download #
# This notebook downloads data for the other notebook examples in this folder using Python `wget`.  The data is downloaded to  `/opt/workspace/datain/flight-data` which is on the *shared-workspace* Docker volume.

# %%
import wget

# %% [markdown]
# #### Flight Data ####
# Download Flight Data from GitHub site [Databricks - Spark The Definitive Guide](https://github.com/databricks/Spark-The-Definitive-Guide)

# %%
mkdir -p /opt/workspace/datain/flight-data

# %%
files = ['2010-summary.csv','2011-summary.csv', '2012-summary.csv', '2013-summary.csv','2014-summary.csv', '2015-summary.csv']
target_path = '/opt/workspace/datain/flight-data'

for f in files:
     print("download {}".format(f))
     wget.download('https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/flight-data/csv/{}'.format(f)
                   , out=target_path)
# Out:
# download 2010-summary.csv
# download 2011-summary.csv
# download 2012-summary.csv
# download 2013-summary.csv
# download 2014-summary.csv
# download 2015-summary.csv

# %% [markdown]
# #### Retail Data ####
# Download the Retail Data from GitHub site [Databricks - Spark The Definitive Guide](https://github.com/databricks/Spark-The-Definitive-Guide) from the`data/retail-data` directory to the workspace `datain/retail-data` directory.

# %%
mkdir -p /opt/workspace/datain/retail-data/by-day

# %%
target_path = '/opt/workspace/datain/retail-data/by-day'

fh = open("./retail_data_day_files.txt", "r")
for f in fh:
    print("download {}".format(f))
    wget.download('https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/retail-data/by-day/{}'.format(f.strip())
                   , out=target_path)
# Out:
# download 2010-12-01.csv
#
# download 2010-12-02.csv
#
# download 2010-12-03.csv
#
# download 2010-12-05.csv
#
# download 2010-12-06.csv
#
# download 2010-12-07.csv
#
# download 2010-12-08.csv
#
# download 2010-12-09.csv
#
# download 2010-12-10.csv
#
# download 2010-12-12.csv
#
# download 2010-12-13.csv
#
# download 2010-12-14.csv
#
# download 2010-12-15.csv
#
# download 2010-12-16.csv
#
# download 2010-12-17.csv
#
# download 2010-12-19.csv
#
# download 2010-12-20.csv
#
# download 2010-12-21.csv
#
# download 2010-12-22.csv
#
# download 2010-12-23.csv
#
# download 2011-01-04.csv
#
# download 2011-01-05.csv
#
# download 2011-01-06.csv
#
# download 2011-01-07.csv
#
# download 2011-01-09.csv
#
# download 2011-01-10.csv
#
# download 2011-01-11.csv
#
# download 2011-01-12.csv
#
# download 2011-01-13.csv
#
# download 2011-01-14.csv
#
# download 2011-01-16.csv
#
# download 2011-01-17.csv
#
# download 2011-01-18.csv
#
# download 2011-01-19.csv
#
# download 2011-01-20.csv
#
# download 2011-01-21.csv
#
# download 2011-01-23.csv
#
# download 2011-01-24.csv
#
# download 2011-01-25.csv
#
# download 2011-01-26.csv
#
# download 2011-01-27.csv
#
# download 2011-01-28.csv
#
# download 2011-01-30.csv
#
# download 2011-01-31.csv
#
# download 2011-02-01.csv
#
# download 2011-02-02.csv
#
# download 2011-02-03.csv
#
# download 2011-02-04.csv
#
# download 2011-02-06.csv
#
# download 2011-02-07.csv
#
# download 2011-02-08.csv
#
# download 2011-02-09.csv
#
# download 2011-02-10.csv
#
# download 2011-02-11.csv
#
# download 2011-02-13.csv
#
# download 2011-02-14.csv
#
# download 2011-02-15.csv
#
# download 2011-02-16.csv
#
# download 2011-02-17.csv
#
# download 2011-02-18.csv
#
# download 2011-02-20.csv
#
# download 2011-02-21.csv
#
# download 2011-02-22.csv
#
# download 2011-02-23.csv
#
# download 2011-02-24.csv
#
# download 2011-02-25.csv
#
# download 2011-02-27.csv
#
# download 2011-02-28.csv
#
# download 2011-03-01.csv
#
# download 2011-03-02.csv
#
# download 2011-03-03.csv
#
# download 2011-03-04.csv
#
# download 2011-03-06.csv
#
# download 2011-03-07.csv
#
# download 2011-03-08.csv
#
# download 2011-03-09.csv
#
# download 2011-03-10.csv
#
# download 2011-03-11.csv
#
# download 2011-03-13.csv
#
# download 2011-03-14.csv
#
# download 2011-03-15.csv
#
# download 2011-03-16.csv
#
# download 2011-03-17.csv
#
# download 2011-03-18.csv
#
# download 2011-03-20.csv
#
# download 2011-03-21.csv
#
# download 2011-03-22.csv
#
# download 2011-03-23.csv
#
# download 2011-03-24.csv
#
# download 2011-03-25.csv
#
# download 2011-03-27.csv
#
# download 2011-03-28.csv
#
# download 2011-03-29.csv
#
# download 2011-03-30.csv
#
# download 2011-03-31.csv
#
# download 2011-04-01.csv
#
# download 2011-04-03.csv
#
# download 2011-04-04.csv
#
# download 2011-04-05.csv
#
# download 2011-04-06.csv
#
# download 2011-04-07.csv
#
# download 2011-04-08.csv
#
# download 2011-04-10.csv
#
# download 2011-04-11.csv
#
# download 2011-04-12.csv
#
# download 2011-04-13.csv
#
# download 2011-04-14.csv
#
# download 2011-04-15.csv
#
# download 2011-04-17.csv
#
# download 2011-04-18.csv
#
# download 2011-04-19.csv
#
# download 2011-04-20.csv
#
# download 2011-04-21.csv
#
# download 2011-04-26.csv
#
# download 2011-04-27.csv
#
# download 2011-04-28.csv
#
# download 2011-05-01.csv
#
# download 2011-05-03.csv
#
# download 2011-05-04.csv
#
# download 2011-05-05.csv
#
# download 2011-05-06.csv
#
# download 2011-05-08.csv
#
# download 2011-05-09.csv
#
# download 2011-05-10.csv
#
# download 2011-05-11.csv
#
# download 2011-05-12.csv
#
# download 2011-05-13.csv
#
# download 2011-05-15.csv
#
# download 2011-05-16.csv
#
# download 2011-05-17.csv
#
# download 2011-05-18.csv
#
# download 2011-05-19.csv
#
# download 2011-05-20.csv
#
# download 2011-05-22.csv
#
# download 2011-05-23.csv
#
# download 2011-05-24.csv
#
# download 2011-05-25.csv
#
# download 2011-05-26.csv
#
# download 2011-05-27.csv
#
# download 2011-05-29.csv
#
# download 2011-05-31.csv
#
# download 2011-06-01.csv
#
# download 2011-06-02.csv
#
# download 2011-06-03.csv
#
# download 2011-06-05.csv
#
# download 2011-06-06.csv
#
# download 2011-06-07.csv
#
# download 2011-06-08.csv
#
# download 2011-06-09.csv
#
# download 2011-06-10.csv
#
# download 2011-06-12.csv
#
# download 2011-06-13.csv
#
# download 2011-06-14.csv
#
# download 2011-06-15.csv
#
# download 2011-06-16.csv
#
# download 2011-06-17.csv
#
# download 2011-06-19.csv
#
# download 2011-06-20.csv
#
# download 2011-06-21.csv
#
# download 2011-06-22.csv
#
# download 2011-06-23.csv
#
# download 2011-06-24.csv
#
# download 2011-06-26.csv
#
# download 2011-06-27.csv
#
# download 2011-06-28.csv
#
# download 2011-06-29.csv
#
# download 2011-06-30.csv
#
# download 2011-07-01.csv
#
# download 2011-07-03.csv
#
# download 2011-07-04.csv
#
# download 2011-07-05.csv
#
# download 2011-07-06.csv
#
# download 2011-07-07.csv
#
# download 2011-07-08.csv
#
# download 2011-07-10.csv
#
# download 2011-07-11.csv
#
# download 2011-07-12.csv
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File /usr/local/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /usr/local/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/local/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/local/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/local/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File /usr/local/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File /usr/local/lib/python3.10/http/client.py:1454, in HTTPSConnection.connect(self)
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File /usr/local/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File /usr/local/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File /usr/local/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# SSLEOFError: EOF occurred in violation of protocol (_ssl.c:997)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[5], line 6
#       4 for f in fh:
#       5     print("download {}".format(f))
# ----> 6     wget.download('https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/retail-data/by-day/{}'.format(f.strip())
#       7                    , out=target_path)
#
# File /usr/local/lib/python3.10/site-packages/wget.py:526, in download(url, out, bar)
#     524 else:
#     525     binurl = url
# --> 526 (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527 filename = detect_filename(url, out, headers)
#     528 if outdir:
#
# File /usr/local/lib/python3.10/urllib/request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
#     244     # Just return the local path and the "headers" for file://
#     245     # URLs. No sense in performing a copy unless requested.
#
# File /usr/local/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/local/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /usr/local/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /usr/local/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/local/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/local/lib/python3.10/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:997)>
